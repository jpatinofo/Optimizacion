# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns  
import functions as f

# %%
df=pd.read_csv('Aportes.csv',parse_dates=True,index_col='Date')
df.head()
# Out:
#              20E   70E   80E  100E  120E  140E  160E  120W   40W   10W  Year  \
# Date
# 2000-01-01 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09  2000
# 2000-01-02 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09  2000
# 2000-01-03 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09  2000
# 2000-01-04  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05  2000
# 2000-01-05  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05  2000
#
#             Month  Value  PosibleNino  PosibleNina  Precipitaciones  \
# Date
# 2000-01-01      1   -1.7            0            0              0.0
# 2000-01-02      1   -1.7            0            0              0.0
# 2000-01-03      1   -1.7            0            0              0.0
# 2000-01-04      1   -1.7            0            0              4.6
# 2000-01-05      1   -1.7            0            1              0.0
#
#             Temperaturas  Humedades  Name  AporCaudal
# Date
# ...

# %%
df.isnull().sum()
# Out:
# 20E                0
# 70E                0
# 80E                0
# 100E               0
# 120E               0
# 140E               0
# 160E               0
# 120W               0
# 40W                0
# 10W                0
# Year               0
# Month              0
# Value              0
# PosibleNino        0
# PosibleNina        0
# Precipitaciones    2
# Temperaturas       2
# Humedades          2
# Name               0
# AporCaudal         0
# dtype: int64

# %%
df.describe()
# Out:
#                20E          70E          80E         100E         120E  \
# count  8637.000000  8637.000000  8637.000000  8637.000000  8637.000000
# mean      0.071914     0.018085    -0.035541    -0.124096    -0.088437
# std       1.006652     1.000860     1.003551     1.009764     1.007672
# min      -3.200000    -2.850000    -3.280000    -3.160000    -3.110000
# 25%      -0.610000    -0.680000    -0.740000    -0.830000    -0.800000
# 50%       0.100000     0.020000    -0.040000    -0.140000    -0.110000
# 75%       0.790000     0.740000     0.680000     0.570000     0.600000
# max       2.820000     3.020000     3.230000     3.520000     3.440000
#
#               140E         160E         120W          40W          10W  \
# count  8637.000000  8637.000000  8637.000000  8637.000000  8637.000000
# mean     -0.102273    -0.061664    -0.009787     0.061261     0.104130
# std       1.008122     1.003510     1.006768     1.015027     1.011442
# ...

# %%
df.drop(['Name','Year','Month','PosibleNino','PosibleNina'],axis=1,inplace=True)
df.head()
# Out:
#              20E   70E   80E  100E  120E  140E  160E  120W   40W   10W  Value  \
# Date
# 2000-01-01 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-02 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-03 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-04  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
# 2000-01-05  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
#
#             Precipitaciones  Temperaturas  Humedades  AporCaudal
# Date
# 2000-01-01              0.0          23.6       96.0       43.51
# 2000-01-02              0.0          26.7       95.0       43.67
# 2000-01-03              0.0          24.0       96.0       41.21
# 2000-01-04              4.6          22.4       98.0       43.80
# 2000-01-05              0.0          21.0       98.0       40.62

# %%
f.plot_time_series(df,'AporCaudal')

# %%
f.acf_pacf_plots(df.AporCaudal)

# %%
df['ValorAnterior']=df['AporCaudal'].shift(1)
df.head()
# Out:
#              20E   70E   80E  100E  120E  140E  160E  120W   40W   10W  Value  \
# Date
# 2000-01-01 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-02 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-03 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-04  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
# 2000-01-05  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
#
#             Precipitaciones  Temperaturas  Humedades  AporCaudal  \
# Date
# 2000-01-01              0.0          23.6       96.0       43.51
# 2000-01-02              0.0          26.7       95.0       43.67
# 2000-01-03              0.0          24.0       96.0       41.21
# 2000-01-04              4.6          22.4       98.0       43.80
# 2000-01-05              0.0          21.0       98.0       40.62
#
#             ValorAnterior
# Date
# 2000-01-01            NaN
# 2000-01-02          43.51
# ...

# %%
# df['AportCaudal2']=df['AporCaudal']-df['ValorAnterior']
# df.head()

# %%
# f.acf_pacf_plots(df.AportCaudal2)

# %%
# f.plot_time_series(df,'AportCaudal2')

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))  # Ajustar el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Matriz de Correlación')
plt.show()

# %% [markdown]
# A partir de la matriz de correlación se define tabajar unicamente con las siguientes variables:
# -Precipitaciones
# -Value (ONI)
# -MJO (Todas)
# -Valor Anterior

# %%
df_final=df.drop(['Temperaturas','Humedades'],axis=1)
df_final
# Out:
#              20E   70E   80E  100E  120E  140E  160E  120W   40W   10W  Value  \
# Date
# 2000-01-01 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-02 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-03 -0.36 -0.69 -0.74 -0.30 -0.28  0.20  0.57  0.79  0.61  0.09   -1.7
# 2000-01-04  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
# 2000-01-05  0.82  0.31 -0.53 -1.02 -1.06 -0.94 -0.57  0.06  0.83  1.05   -1.7
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 2023-08-27  0.21 -0.07  0.23 -0.11 -0.32 -0.40 -0.24  0.07  0.29  0.38    1.3
# 2023-08-28  0.21 -0.07  0.23 -0.11 -0.32 -0.40 -0.24  0.07  0.29  0.38    1.3
# 2023-08-29  0.21 -0.07  0.23 -0.11 -0.32 -0.40 -0.24  0.07  0.29  0.38    1.3
# 2023-08-30  0.21 -0.07  0.23 -0.11 -0.32 -0.40 -0.24  0.07  0.29  0.38    1.3
# 2023-08-31  0.21 -0.07  0.23 -0.11 -0.32 -0.40 -0.24  0.07  0.29  0.38    1.3
#
# ...
